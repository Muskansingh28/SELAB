# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskansingh28/SELAB/blob/main/se_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time):
        a = 0.1
        b = -1
        c = 30
        temp = a * (Time**2) + b * Time + c
        return temp
def main():
        time_v = np.linspace(0, 10, 50)
        temp_hardcoded = quad_model(time_v)
        plt.plot(time_v, temp_hardcoded, label="hardcoded values")
        plt.xlabel("time")
        plt.ylabel('temp')
        plt.legend()
        plt.title("weather modeling with user given values and range in QE")
        plt.show()
if __name__ == "__main__":
        main()

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time) :
          a=int(input("enter the value of a "))
          b=int(input("enter the value of b "))
          c=int(input("enter the value of c "))
          temp=a*(Time**2)+b*Time+c
          return temp
def main():
          print("give a time range")
          x=int(input("enter the start range"))
          y=int(input("enter the final range"))
          time_v=np.linspace(x,y,50)
          temp_user=quad_model(time_v)
          plt.plot(time_v,temp_user,label="user given values")
          plt.xlabel("time")
          plt.ylabel('temp')
          plt.legend()
          plt.title("weather modeling with user given values and range in QE")
          plt.show()
if __name__=="__main__":
          main()
# Out:
# give a time range
# enter the start range10
# enter the final range100
# enter the value of a 30
# enter the value of b 40
# enter the value of c 60

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp
def main():
    num_sets = int(input("Enter the number of coefficient sets: "))
    all_sets = []
    for _ in range(num_sets):
        a = float(input("Enter the value of 'a': "))
        b = float(input("Enter the value of 'b': "))
        c = float(input("Enter the value of 'c': "))
        all_sets.append((a, b, c))
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))
    time_v = np.linspace(x, y, 50)
    plt.figure(figsize=(8, 6))
    for coeffs in all_sets:
        temp_user = quad_model(time_v, coeffs)
        plt.plot(time_v, temp_user, label=f"Set: {coeffs}")
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather modeling with user given coefficient sets")
    plt.grid(True)
    plt.show()
if __name__ == "__main__":
    main()
# Out:
# Enter the number of coefficient sets: 3
# Enter the value of 'a': 1
# Enter the value of 'b': 3
# Enter the value of 'c': 5
# Enter the value of 'a': 10
# Enter the value of 'b': 20
# Enter the value of 'c': 30
# Enter the value of 'a': 11
# Enter the value of 'b': 22
# Enter the value of 'c': 33
# Give a time range:
# Enter the start range: 0
# Enter the final range: 100

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp
def main():
    set1 = {float(input("Enter the value of 'a': ")), float(input("Enter the value of 'b': ")), float(input("Enter the value of 'c': "))}
    print(set1)
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))
    time_v = np.linspace(x, y, 50)
    temp_user = quad_model(time_v, set1)
    plt.plot(time_v, temp_user, label="user given values")
    plt.xlabel("time")
    plt.ylabel("temp")
    plt.legend()
    plt.title("Weather modeling with user given values and range in QE")
    plt.show()
if __name__ == "__main__":
    main()
# Out:
# Enter the value of 'a': 10
# Enter the value of 'b': 20
# Enter the value of 'c': 30
# {10.0, 20.0, 30.0}
# Give a time range:
# Enter the start range: 0
# Enter the final range: 50

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(time):
  a=0.1
  b=-1
  c=30
  temp = a * (time**2) + b * time + c
  return temp
def quad_model2(time):
  a=float(input('Enter a value:'))
  b=float(input('Enter b value:'))
  c=float(input('Enter c value:'))
  temp = a * (time**2) + b * time + c
  return temp
def main():
  time_value=np.linspace(0, 10, 50)
  temp1_user = quad_model(time_value)
  plt.plot(time_value, temp1_user,label='hard-coded')
  temp2_user = quad_model2(time_value)
  plt.plot(time_value, temp2_user,label='user given input')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather Modeling ')
  plt.grid(True)
  plt.show()
if __name__ == '__main__':
    main()
# Out:
# Enter a value:40
# Enter b value:50
# Enter c value:60
